# %% [markdown]
# ### <center> DAIMOND PRICE PREDICTION

# %% [markdown]
# ###
# THIS IS A REGRESSION KIND OF PROBLEM IN WHICH WE HAVE TO PREDICT THE PRICE OF DAIMOND

# %% [markdown]
# ![daimond-2.webp](attachment:daimond-2.webp)

# %% [markdown]
# ### DATASET DESCRIPTION
#   These dataset contain 10 features in which 'Price(in US dollars)' is dependent feature. The goal is we have to predict the price of Diamond using different Regression Algorithms

# %% [markdown]
# ###
# LOADING NECESSARIES

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import klib as k
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import Lasso,LinearRegression,LogisticRegression,Ridge
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("diamonds.csv")

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#    carat         cut color clarity  depth  table  price   'x'   'y'   'z'
# 0   0.23    b'Ideal'  b'E'  b'SI2'   61.5   55.0  326.0  3.95  3.98  2.43
# 1   0.21  b'Premium'  b'E'  b'SI1'   59.8   61.0  326.0  3.89  3.84  2.31
# 2   0.23     b'Good'  b'E'  b'VS1'   56.9   65.0  327.0  4.05  4.07  2.31
# 3   0.29  b'Premium'  b'I'  b'VS2'   62.4   58.0  334.0  4.20  4.23  2.63
# 4   0.31     b'Good'  b'J'  b'SI2'   63.3   58.0  335.0  4.34  4.35  2.75

# %% [markdown]
# ###
# removing letter b from cut coloumn

# %%
df['cut'] = df['cut'].str.replace('^b','')

# %%
df['clarity'] = df['clarity'].str.replace('^b','')
df['color'] = df['color'].str.replace('^b','')

# %%
df
# Out:
#        carat          cut color clarity  depth  table   price   'x'   'y'  \
# 0       0.23      'Ideal'   'E'   'SI2'   61.5   55.0   326.0  3.95  3.98
# 1       0.21    'Premium'   'E'   'SI1'   59.8   61.0   326.0  3.89  3.84
# 2       0.23       'Good'   'E'   'VS1'   56.9   65.0   327.0  4.05  4.07
# 3       0.29    'Premium'   'I'   'VS2'   62.4   58.0   334.0  4.20  4.23
# 4       0.31       'Good'   'J'   'SI2'   63.3   58.0   335.0  4.34  4.35
# ...      ...          ...   ...     ...    ...    ...     ...   ...   ...
# 53935   0.72      'Ideal'   'D'   'SI1'   60.8   57.0  2757.0  5.75  5.76
# 53936   0.72       'Good'   'D'   'SI1'   63.1   55.0  2757.0  5.69  5.75
# 53937   0.70  'Very Good'   'D'   'SI1'   62.8   60.0  2757.0  5.66  5.68
# 53938   0.86    'Premium'   'H'   'SI2'   61.0   58.0  2757.0  6.15  6.12
# 53939   0.75      'Ideal'   'D'   'SI2'   62.2   55.0  2757.0  5.83  5.87
#
#         'z'
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 10 columns]

# %%
cut_price = df.groupby(['cut'])['price'].sum()
plt.title("RELATION OF PRICE WITH COLOUMN CUT")
cut_price.plot.pie();

# %%
cut_price = df.groupby(['clarity'])['price'].sum()
plt.title("RELATION OF PRICE WITH COLOUMN CLARITY")
cut_price.plot.pie();

# %%
cut_price = df.groupby(['color'])['price'].sum()
plt.title("RELATION OF PRICE WITH COLOUMN COLOR")
cut_price.plot.pie();

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  float64
#  7   'x'      53940 non-null  float64
#  8   'y'      53940 non-null  float64
#  9   'z'      53940 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull().mean()*100
# Out:
# carat      0.0
# cut        0.0
# color      0.0
# clarity    0.0
# depth      0.0
# table      0.0
# price      0.0
# 'x'        0.0
# 'y'        0.0
# 'z'        0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.drop_duplicates()
# Out:
#        carat          cut color clarity  depth  table   price   'x'   'y'  \
# 0       0.23      'Ideal'   'E'   'SI2'   61.5   55.0   326.0  3.95  3.98
# 1       0.21    'Premium'   'E'   'SI1'   59.8   61.0   326.0  3.89  3.84
# 2       0.23       'Good'   'E'   'VS1'   56.9   65.0   327.0  4.05  4.07
# 3       0.29    'Premium'   'I'   'VS2'   62.4   58.0   334.0  4.20  4.23
# 4       0.31       'Good'   'J'   'SI2'   63.3   58.0   335.0  4.34  4.35
# ...      ...          ...   ...     ...    ...    ...     ...   ...   ...
# 53935   0.72      'Ideal'   'D'   'SI1'   60.8   57.0  2757.0  5.75  5.76
# 53936   0.72       'Good'   'D'   'SI1'   63.1   55.0  2757.0  5.69  5.75
# 53937   0.70  'Very Good'   'D'   'SI1'   62.8   60.0  2757.0  5.66  5.68
# 53938   0.86    'Premium'   'H'   'SI2'   61.0   58.0  2757.0  6.15  6.12
# 53939   0.75      'Ideal'   'D'   'SI2'   62.2   55.0  2757.0  5.83  5.87
#
#         'z'
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53794 rows x 10 columns]

# %%
df.describe()
# Out:
#               carat         depth         table         price           'x'  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                 'y'           'z'
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
k.dist_plot(df);
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.

# %%
df
# Out:
#        carat          cut color clarity  depth  table   price   'x'   'y'  \
# 0       0.23      'Ideal'   'E'   'SI2'   61.5   55.0   326.0  3.95  3.98
# 1       0.21    'Premium'   'E'   'SI1'   59.8   61.0   326.0  3.89  3.84
# 2       0.23       'Good'   'E'   'VS1'   56.9   65.0   327.0  4.05  4.07
# 3       0.29    'Premium'   'I'   'VS2'   62.4   58.0   334.0  4.20  4.23
# 4       0.31       'Good'   'J'   'SI2'   63.3   58.0   335.0  4.34  4.35
# ...      ...          ...   ...     ...    ...    ...     ...   ...   ...
# 53935   0.72      'Ideal'   'D'   'SI1'   60.8   57.0  2757.0  5.75  5.76
# 53936   0.72       'Good'   'D'   'SI1'   63.1   55.0  2757.0  5.69  5.75
# 53937   0.70  'Very Good'   'D'   'SI1'   62.8   60.0  2757.0  5.66  5.68
# 53938   0.86    'Premium'   'H'   'SI2'   61.0   58.0  2757.0  6.15  6.12
# 53939   0.75      'Ideal'   'D'   'SI2'   62.2   55.0  2757.0  5.83  5.87
#
#         'z'
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 10 columns]

# %%
df.cut.unique()
# Out:
# array(["'Ideal'", "'Premium'", "'Good'", "'Very Good'", "'Fair'"],
#       dtype=object)

# %% [markdown]
# ### changing catagorical data to numerical

# %%
le=LabelEncoder()

# %%
df["cut"]=le.fit_transform(df.cut)

# %%
df["color"]=le.fit_transform(df.color)
df["clarity"]=le.fit_transform(df.clarity)

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table   price   'x'   'y'   'z'
# 0       0.23    2      1        3   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72    2      0        2   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72    1      0        2   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70    4      0        2   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    3      4        3   61.0   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### KDA PLOT

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.kdeplot(x=df[i],color="GREEN")
        plt.show();

# %% [markdown]
#   ### HISTOGRAM

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.histplot(x=df[i],color="GREEN")
        plt.show();

# %% [markdown]
# ### HEATMAP

# %%
k.corr_plot(data=df,target="price");

# %%
k.clean_column_names(df)
# Out:
#        carat  cut  color  clarity  depth  table   price     x     y     z
# 0       0.23    2      1        3   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21    3      1        2   59.8   61.0   326.0  3.89  3.84  2.31
# 2       0.23    1      1        4   56.9   65.0   327.0  4.05  4.07  2.31
# 3       0.29    3      5        5   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31    1      6        3   63.3   58.0   335.0  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72    2      0        2   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72    1      0        2   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70    4      0        2   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    3      4        3   61.0   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75    2      0        3   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### boxplot

# %%
for i in df.columns:
    if df[i].dtype!="object":
            sns.boxplot(y=df[i],color="red")
            plt.show()

# %% [markdown]
# ### cleaning the outliers

# %%
def outlier(col):
    Q3, Q1= np.nanpercentile(col,[75,25])
    iqr=Q3-Q1
    ul=Q3+1.5*iqr
    ll=Q1-1.5*iqr
    return ul, ll

# %%
for column in df.columns:
    if df[column].dtype !="object":
        ul,ll=outlier(df[column])
        df[column]=np.where((df[column]>ul)|(df[column]<ll),np.nan,df[column])

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.boxplot(y=df[i],color="green")
        plt.show()

# %% [markdown]
# ### droping nan values

# %%
df.isnull().sum()
# Out:
# carat      1889
# cut        1610
# color         0
# clarity       0
# depth      2545
# table       605
# price      3540
# x            32
# y            29
# z            49
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### REGRESSION

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table   price     x     y     z
# 0       0.23  2.0    1.0      3.0   61.5   55.0   326.0  3.95  3.98  2.43
# 1       0.21  3.0    1.0      2.0   59.8   61.0   326.0  3.89  3.84  2.31
# 3       0.29  3.0    5.0      5.0   62.4   58.0   334.0  4.20  4.23  2.63
# 4       0.31  1.0    6.0      3.0   63.3   58.0   335.0  4.34  4.35  2.75
# 5       0.24  4.0    6.0      7.0   62.8   57.0   336.0  3.94  3.96  2.48
# ...      ...  ...    ...      ...    ...    ...     ...   ...   ...   ...
# 53935   0.72  2.0    0.0      2.0   60.8   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72  1.0    0.0      2.0   63.1   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  4.0    0.0      2.0   62.8   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86  3.0    4.0      3.0   61.0   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75  2.0    0.0      3.0   62.2   55.0  2757.0  5.83  5.87  3.64
#
# [47194 rows x 10 columns]

# %%
x=df[["carat","cut","color","depth","table","x","y","z"]].values

# %%
y=df[["price"]].values

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %% [markdown]
# ### CROSS VALIDATION

# %%
models = {
    "LinearRegression": LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "RandomForestRegressor":RandomForestRegressor()
}

# %%
for name, model in models.items():
    scores = cross_val_score(model, x,y, scoring="neg_mean_squared_error",cv=10,n_jobs=-1)
    print("cross validation model : {}".format(name))
    rmse = np.sqrt(-scores)
    rmse_average = np.mean(rmse)
    print("AVERAGE RMSE: ",rmse_average)
    print("*"*100)
# Out:
# cross validation model : LinearRegression
# AVERAGE RMSE:  913.5108524392497
# ****************************************************************************************************
# cross validation model : Lasso
# AVERAGE RMSE:  915.3249995921875
# ****************************************************************************************************
# cross validation model : Ridge
# AVERAGE RMSE:  913.55287788604
# ****************************************************************************************************
# cross validation model : DecisionTreeRegressor
# AVERAGE RMSE:  1194.649634738504
# ****************************************************************************************************
# cross validation model : RandomForestRegressor
# AVERAGE RMSE:  960.2945215787025
# ****************************************************************************************************

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
models={
    "linearregression":LinearRegression(),
    "ridge":Ridge(),
    "lasso":Lasso(),
    "decisiontreeregressor":DecisionTreeRegressor(),
    "randomforestregressor":RandomForestRegressor(random_state=0)
}

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    print("model trained with{}".format(name))
    training_score =model.score(x_train,y_train)*100
    testing_score =model.score(x_test,y_test)*100
    score =r2_score(y_test,model.predict(x_test))*100
    mae = mean_absolute_error(y_test, model.predict(x_test))
    mse= mean_squared_error(y_test,model.predict(x_test))
    rmse= np.sqrt(mse)
    print("r2score: ",score)
    print("training_score:",training_score)
    print("testing_score:",testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test:",rmse)
    print("   "*105)
# Out:
# model trained withlinearregression
# r2score:  87.55251815842428
# training_score: 87.38469216635598
# testing_score: 87.55251815842428
# mae: 624.7594735382289
# mse: 932980.6032248391
# rmse_test: 965.9092106532783
#
# model trained withridge
# r2score:  87.55279093081424
# training_score: 87.38463571217746
# testing_score: 87.55279093081424
# mae: 624.7481357883416
# mse: 932960.158017353
# rmse_test: 965.8986271950866
#
# model trained withlasso
# r2score:  87.52939650135359
# training_score: 87.35764983737143
# testing_score: 87.52939650135359
# mae: 624.4404830162945
# mse: 934713.6491401434
# rmse_test: 966.8059004475218
#
# model trained withdecisiontreeregressor
# r2score:  81.87596622473428
# training_score: 99.98387913700269
# testing_score: 81.87596622473428
# mae: 653.0230603524385
# mse: 1358457.251010877
# rmse_test: 1165.5287431079842
#
# model trained withrandomforestregressor
# r2score:  90.62408743783168
# training_score: 98.65913013618713
# testing_score: 90.62408743783168
# mae: 488.8764346862981
# mse: 702756.1613962392
# rmse_test: 838.3055298614219

# %% [markdown]
# ### model training

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
#  ### PRICE PREDICTION

# %%
y_pred = model.predict(x)

# %%
op=pd.DataFrame(zip(y,y_pred),columns=("ACTUAL","PREDICTED"),dtype=float)

# %%
mod

# %% [markdown]
# ### scatterplot

# %%
plt.figure(figsize=(10,6))
plt.xticks()
sns.scatterplot(data=op,x='ACTUAL',y="PREDICTED")
plt.show();

# %% [markdown]
# ### LINE PLOT

# %%
plt.figure(figsize=(10,6))
plt.xticks()
sns.lineplot(data=op,x='ACTUAL',y="PREDICTED")
plt.show();

# %% [markdown]
# ### CONCLUTION
#
# ###
# OUR PREDICTED VALUE IS  98% ACCURATE WITH ACTUAL VALUE BY USING  RANDOM FOREST REGRESSION
